# %% [markdown]
# # Sistema de gestión de notas académicas usando diccionarios

# %%
registro = {
  "Juan": {
    "Matemáticas": 4.5,
    "Inglés": 3.8,
    "Programación": 4.2,
    "Estadística": 3.9
  },
  "Ana": {
    "Matemáticas": 3.5,
    "Inglés": 4.6,
    "Programación": 4.8,
    "Estadística": 4.3
  },
  "Luis": {
    "Matemáticas": 4.0,
    "Inglés": 3.7,
    "Programación": 4,
    "Estadística": 4.1
  },
}
